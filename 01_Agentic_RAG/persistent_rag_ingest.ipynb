# %% [markdown]
# # Building a persistent ingestion data pipeline

# %%
from ingest import load_faq_data
documents =  load_faq_data()

# %%
len(documents)
# Out:
# 1350

# %%
from sqlitesearch import TextSearchIndex
import time

index = TextSearchIndex(
    text_fields=['question', 'section', 'answer'],
    keyword_fields=['course'],
    db_path='faq.db'
)

# %%
# Adding documents to the db

for doc in documents:
    index.add(doc)
    print(f'Added: {doc["question"][:60]}......')
    time.sleep(0.5)


index.close()
# Out:
# Added: Course: When does the course start?......
# Added: Course: What are the prerequisites for this course?......
# Added: Course: Can I still join the course after the start date?......
# Added: Course: I have registered for the Data Engineering Bootcamp.......
# Added: Course: What can I do before the course starts?......
# Added: Course: how many Zoomcamps run in a year?......
# Added: Course: Is the current cohort going to be different from the......
# Added: Course - Can I follow the course after it finishes?......
# Added: Course: Can I get support if I take the course in the self-p......
# Added: Course: Which YouTube playlist should I follow?......
# Added: Course: How many hours per week am I expected to spend on th......
# Added: Office Hours: I can’t attend the “Office hours” / workshop, ......
# Added: Edit Course Profile.......
# Added: Certificate: Do I need to do the homeworks to get the certif......
# Added: Certificate - Can I follow the course in a self-paced mode a......
# Added: Homework: What are homework and project deadlines?......
# Added: Homework: Are late submissions of homework allowed?......
# Added: Homework: What is the homework URL in the homework link?......
# Added: Leaderboard: how do I find myself on the leaderboard?......
# Added: Besides the “Office Hour” which are the live zoom calls?......
# Added: How can we contribute to the course?......
# Added: Any books or additional resources you recommend?......
# Added: Project: What is Project Attempt #1 and Project Attempt #2 e......
# Added: How do I use Git / GitHub for this course?......
# Added: How do I get my certificate?......
# Added: Homework and Leaderboard: how does the points system work?......
# Added: Certificate - I submitted the project, so why isn't my certi......
# Added: Environment: which Python version should I use?......
# Added: Where should I run the course: local machine, GitHub Codespa......
# Added: Environment - Could not establish connection to "MyServerNam......
# Added: Why does the course use GCP and not AWS or Azure?......
# Added: Environment: shell scripts (*.sh) don't work for Windows use......
# Added: How to troubleshoot issues and ask good questions......
# Added: Git Bash: Backslash as an escape character in Git Bash for W......
# Added: VS Code: Tab using spaces......
# Added: Opening an HTML file with a Windows browser from Linux runni......
# Added: GitHub Codespaces: How to store secrets......
# Added: Set up Chrome Remote Desktop for Linux on Compute Engine......
# Added: GitHub Codespaces: Running pgadmin in Docker......
# Added: VMs: What do I do if my VM runs out of space?......
# Added: How to run Python as a startup script?......
# Added: SSH Error: ssh: Could not resolve hostname linux: Name or se......
# Added: Jupyter: Install nbconvert, fix 'Failed to spawn' nbconvert ......
# Added: Alternative way to convert Jupyter notebook to Python script......
# Added: Should I use Anaconda for this course?......
# Added: Which operating systems does the course support?......
# Added: Can I use AWS / Snowflake / Azure instead of GCP for the pro......
# Added: Do I have to pay for GCP?......
# Added: GCP Free Trial vs Sandbox: which one should I use for the co......
# Added: My country isn't supported by GCP / my card is rejected. Wha......
# Added: GitHub Codespaces: what uses up memory and storage?......
# Added: Taxi Data: Yellow Taxi Trip Records downloading error......
# Added: Taxi Data: How to handle *.csv.gz taxi data files?......
# Added: Taxi Data: Data Dictionary for NY Taxi data?......
# Added: Taxi Data: Unzip csv.gz file......
# Added: wget is not recognized as an internal or external command......
# Added: wget - ERROR: cannot verify <website> certificate  (MacOS)......
# Added: CURL: curl: (6) Could not resolve host: output.csv......
# Added: Why does wget fail to download the CloudFront parquet file e......
# Added: Docker: Cannot connect to Docker daemon at unix:///var/run/d......
# Added: Docker - error during connect: In the default daemon configu......
# Added: Docker: docker pull dbpage......
# Added: docker + Postgres: permission errors on the data directory (......
# Added: Docker: Docker won't start or is stuck in settings (Windows ......
# Added: Docker: Should I run docker commands from the windows file s......
# Added: Docker: The input device is not a TTY (Docker run for Window......
# Added: Docker: Cannot pip install on Docker container (Windows)......
# Added: docker on Windows: volume mount path syntax (Git Bash, MINGW......
# Added: Docker: Setting up Docker on Mac......
# Added: How can I back up and restore PostgreSQL data stored in a Do......
# Added: Docker: ERRO[0000] error waiting for container: context canc......
# Added: Docker: Docker network name......
# Added: Docker: Error response from daemon: Conflict. The container ......
# Added: docker compose: "could not translate host name pgdatabase / ......
# Added: Docker: Cannot install docker on MacOS/Windows 11 VM running......
# Added: Docker: Connecting from VS Code......
# Added: Docker: How to stop a container?......
# Added: Docker: Docker not installable on Ubuntu......
# Added: What's the difference between -i and -t in docker run -it?......
# Added: Docker-Compose: PgAdmin – no database in PgAdmin......
# Added: pgAdmin: persist server / connection settings across contain......
# Added: Docker: Docker engine stopped_failed to fetch extensions......
# Added: docker compose: installation problems (binary not found, exe......
# Added: Docker-Compose: Errors pertaining to docker-compose.yml and ......
# Added: Docker: Postgres container fails to launch with exit code (1......
# Added: WSL: Insufficient system resources exist to complete the req......
# Added: WSL: WSL integration with Ubuntu unexpectedly stopped with e......
# Added: WSL: Permissions too open at Windows......
# Added: WSL: Could not resolve host name......
# Added: Error: error starting userland proxy: listen tcp4 0.0.0.0:80......
# Added: Can I run Docker Engine directly in WSL2 (Ubuntu) without Do......
# Added: Docker: Docker-compose takes infinitely long to install zip ......
# Added: pgcli / Postgres: troubleshooting connection failures (FATAL......
# Added: How do I ensure that the ingestion pipeline runs successfull......
# Added: PGCLI: Should we run pgcli inside another docker container?......
# Added: pgcli: PermissionError: [Errno 13] Permission denied: '~/.co......
# Added: PGCLI - pgcli: command not found......
# Added: PGCLI - running in a Docker container......
# Added: RRPGCLI: Case sensitive use of “Quotations” around columns w......
# Added: PGCLI - error column c.relhasoids does not exist......
# Added: Postgres: bind: address already in use......
# Added: Postgres: "Column does not exist" but it actually does (Pysc......
# Added: pgAdmin: Create server dialog does not appear......
# Added: pgAdmin: CSRF session token is missing error – how to fix in......
# Added: pgAdmin - Can not access/open the PgAdmin address via browse......
# Added: Python: Ingestion with Jupyter notebook - missing 100000 rec......
# Added: IPython - Pandas parsing dates with "read_csv"......
# Added: Python: Python can't ingest data from the GitHub link provid......
# Added: Python: Pandas can read *.csv.gzip......
# Added: Python: How to iterate through and ingest parquet file......
# Added: SQLAlchemy / psycopg: ImportError or NoSuchModuleError when ......
# Added: Python - SQLAlchemy - read_sql_query() throws "'OptionEngine......
# Added: SQL: SELECT * FROM zones_taxi WHERE Zone='Astoria Zone'; Err......
# Added: SQL: SELECT Zone FROM taxi_zones Error Column Zone doesn't e......
# Added: Postgres fails to start after upgrading from postgres:16 to ......
# Added: How to fix “connection failed: connection to server at "127.......
# Added: Why is my table not being created in PostgreSQL when I submi......
# Added: GCP: Static vs Ephemeral IP / Setting up static IP for VM......
# Added: GCP: "The installer is unable to automatically update your s......
# Added: GCP: Project creation failed: HttpError accessing … Requeste......
# Added: GCP: The project to be billed is associated with an absent b......
# Added: GCP: OR-CBAT-15 ERROR Google cloud free trial account......
# Added: GCP: Where can I find the “ny-rides.json” file?......
# Added: GCP: "Failed to load" when accessing Compute Engine’s metada......
# Added: GCP: Do I need to delete my instance in Google Cloud?......
# Added: GCP: SSH public key error - multiple users / usernames......
# Added: GCP: Virtual Machine (VM) Size, Slow, Clean Up......
# Added: Billing: Billing account has not been enabled for this proje......
# Added: GCP - Windows Google Cloud SDK install issue:......
# Added: GCP: I cannot get my Virtual Machine to start because GCP ha......
# Added: GCP VM: Is it necessary to use a GCP VM? When is it useful?......
# Added: GCP VM - mkdir: cannot create directory ‘.ssh’: Permission d......
# Added: GCP VM: Error while saving the file in VM via VS Code......
# Added: GCP VM: VM connection request timeout......
# Added: GCP VM: connect to host port 22 no route to host......
# Added: GCP VM: Port forwarding from GCP without using VS Code......
# Added: GCP gcloud + MS VS Code - gcloud auth hangs......
# Added: GCP: How do I create a service account key when 'service acc......
# Added: GCP VM: SSH suddenly stopped working after a restart......
# Added: GCP VM: If you have lost SSH access to your machine due to l......
# Added: SSH error in VS Code - “Could not establish connection to "d......
# Added: Terraform: Could not reach provider registry in restricted r......
# Added: Terraform: Error: Post "[storage.googleapis.com](https://sto......
# Added: Terraform: Install for WSL......
# Added: Terraform: Error acquiring the state lock......
# Added: Terraform: Error 400 Bad Request. Invalid JWT Token on WSL.......
# Added: Terraform - Error 403 : Access denied......
# Added: Terraform: Do I need to make another service account for Ter......
# Added: Terraform: Where can I download the Terraform binary for Lin......
# Added: Terraform: Terraform initialized in an empty directory! The ......
# Added: Terraform - Error creating Dataset: googleapi: Error 403: Re......
# Added: stoTerraform - Error creating Bucket: googleapi: Error 403: ......
# Added: Terraform: google provider requires credentials.......
# Added: Terraform: Teardown of BigQuery Dataset......
# Added: Terraform Error 412: Request violates constraint 'constraint......
# Added: What does concurrency mean in Kestra, and how does it work?......
# Added: Where are the FAQ questions from the previous cohorts for th......
# Added: How do I launch Kestra?......
# Added: docker: Error response from daemon: mkdir C:\Program Files\G......
# Added: Adding a pgadmin service with volume mounting to the docker-......
# Added: Running out of storage when using Kestra with Postgres on a ......
# Added: Kestra: how do I authenticate to Google Cloud with a service......
# Added: Why can a Kestra workflow show successful upstream tasks eve......
# Added: Storage: Bucket Permission Denied Error when running the gcp......
# Added: Invalid dataset ID Error when running the gcp_setup flow......
# Added: Getting SIGILL in JRE when running latest kestra image on Ma......
# Added: Kestra: "host.docker.internal" connection failures on Linux......
# Added: How to configure and run a Python script in Kestra Docker on......
# Added: Why are dataset row counts computed in PostgreSQL instead of......
# Added: Why does Kestra support conditional branching within a singl......
# Added: Why can't row count questions in Homework 2 be answered dire......
# Added: Why does Kestra use IANA timezone identifiers instead of off......
# Added: Why doesn’t Kestra automatically convert printed task output......
# Added: Why must a file be declared again under outputFiles for it t......
# Added: Why does Kestra need access to the Docker socket?......
# Added: Why does the CSV file size shown in the Kestra Outputs tab d......
# Added: Can I run my dbt project from Kestra?......
# Added: How can I edit Kestra flows locally with Docker Compose and ......
# Added: GitHub Codespaces: ERR_EMPTY_RESPONSE when accessing Kestra ......
# Added: Kestra: Backfill showing getting executed but not getting re......
# Added: How to fix Python logs shown as Kestra error messages?......
# Added: GCS Bucket - error when writing data from web to GCS:......
# Added: GCS Bucket - te table: Error while reading data, error messa......
# Added: GCS Bucket: Fix Error when importing FHV data to GCS......
# Added: GCS Bucket - Load Data From URL list in to GCP Bucket......
# Added: GCS Bucket - I query my dataset and get a Bad character (ASC......
# Added: GCP BQ: "bq: command not found"......
# Added: GCP: Caution in using BigQuery - bigquery:no......
# Added: BigQuery: "Cannot read and write in different locations" whe......
# Added: GCP BQ: Remember to save your queries......
# Added: GCP BQ: Can I use BigQuery for real-time analytics in this p......
# Added: GCP BQ: Unable to load data from external tables into a mate......
# Added: GCP BQ: Error Message in BigQuery: annotated as a valid Time......
# Added: BigQuery: Datetime columns in Parquet files created from Pan......
# Added: GCP: BQ - Create External Table using Python......
# Added: GCP BQ: Check BigQuery Table Exist And Delete......
# Added: GCP BQ - Error: Missing close double quote (") character......
# Added: GCP BQ - Tip: Using Cloud Function to read csv.gz files from......
# Added: GCP BQ: When querying two different tables, external and mat......
# Added: GCP BQ: How to handle type error from BigQuery and Parquet d......
# Added: GCP BQ: Invalid project ID. Project IDs must contain 6-63 lo......
# Added: BigQuery limits: partitioning columns, clustering columns, p......
# Added: How to obtain the DDL of a table in BigQuery?......
# Added: GCP BQ: DATE() Error in BigQuery......
# Added: GCP BQ: When trying to cluster by DATE(tpep_pickup_datetime)......
# Added: BigQuery: native tables vs external tables — what's the diff......
# Added: Why does my partitioned table in BigQuery show as non-partit......
# Added: GCP BQ ML: Unable to run command (shown in video) to export ......
# Added: GCP BQ ML - Export ML model to make predictions does not wor......
# Added: Homework: What does it mean “Stop with loading the files int......
# Added: Homework: Reading parquets from nyc.gov directly into pandas......
# Added: Homework: Uploading files to GCS via GUI......
# Added: Homework - Qn 5: The partitioned/clustered table isn’t givin......
# Added: Homework: Qn 6: Did anyone get an exact match for one of the......
# Added: Why does selecting fewer columns reduce the number of bytes ......
# Added: How do you connect BigQuery with BI tools like Looker Studio......
# Added: Python: invalid start byte Error Message......
# Added: Python: Generators in Python......
# Added: Python: Easiest way to read multiple files at the same time?......
# Added: Python: These won't work. You need to make sure you use Int6......
# Added: How can I estimate BigQuery query costs over a time window a......
# Added: How do you partition and cluster a table in BigQuery for bet......
# Added: How do I manage security and access control in a BigQuery da......
# Added: Why does the estimate of Bytes Processed for COUNT(*) stay a......
# Added: Why are there unexpected years in lpep_pickup_datetime after......
# Added: How can I sync data from PostgreSQL to BigQuery for analytic......
# Added: How do I structure a layered data warehouse (raw, clean, ana......
# Added: When should partitioning be used instead of clustering, and ......
# Added: Warning when run load_yellow_data python script......
# Added: What is the difference between ref() and source() in dbt?......
# Added: dbt cloud Developer......
# Added: DBT-Config ERROR on CLOUD IDE: No dbt_project.yml found at e......
# Added: dbt + BigQuery: "Dataset was not found in location" / region......
# Added: Setup: No development environment......
# Added: Setup: Connecting dbt Cloud with BigQuery Error......
# Added: Setup: Failed to clone repository.......
# Added: Errors when I start the server in dbt cloud: Failed to start......
# Added: dbt: Command 'dbt' not found after installing dbt—how can I ......
# Added: Setup: Your IDE session was unable to start. Please contact ......
# Added: DBT: I am having problems with columns datatype while runnin......
# Added: Ingestion: When attempting to use the provided quick script ......
# Added: Hack to load yellow and green trip data for 2019 and 2020......
# Added: dbt: dbt_utils.surrogate_key has been renamed to dbt_utils.g......
# Added: dbt + BigQuery: Access Denied / permission denied for the se......
# Added: When you are getting error dbt_utils not found......
# Added: Lineage is currently unavailable. Check that your project do......
# Added: Build: Why do my Fact_trips only contain a few days of data?......
# Added: Build: Why do my fact_trips only contain one month of data?......
# Added: BigQuery returns an error when I try to run the dm_monthly_z......
# Added: DBT: I ran dbt run without specifying variable which gave me......
# Added: Why do we need the Staging dataset?......
# Added: DBT: Docs Served but Not Accessible via Browser......
# Added: dbt + git: the main branch is "read-only" — how do I make ch......
# Added: dbt CI: setting up Continuous Integration with GitHub......
# Added: Compilation Error: Model 'model.my_new_project.stg_green_tri......
# Added: Compilation Error in test accepted_values_stg_green_tripdata......
# Added: dbt: macro errors with get_payment_type_description(payment_......
# Added: Troubleshooting in dbt:......
# Added: DBT: Why changing the target schema to “marts” actually crea......
# Added: How to set subdirectory of the github repository as the dbt ......
# Added: Compilation Error: Model 'model.XXX' (models/<model_path>/XX......
# Added: Compilation Error: Model '<model_name>' (<model_path>) depen......
# Added: When loading GitHub repo raise exception that 'taxi_zone_loo......
# Added: Inconsistent number of rows when re-running fact_trips model......
# Added: CREATE TABLE has columns with duplicate name locationid.......
# Added: "Bad int64 value" / Parquet column has type DOUBLE which doe......
# Added: The - vars argument must be a YAML dictionary, but was of ty......
# Added: Could not parse the dbt project. Please check that the repos......
# Added: How do I migrate from a dbt Cloud managed repository to a Gi......
# Added: Made change to your modeling files and commit to your develo......
# Added: Setup: I’ve set Github and Bigquery to dbt successfully. Why......
# Added: DBT: Running `dbt run --models stg_green_tripdata --var 'is_......
# Added: DBT: Error: No module named 'pytz' while setting up dbt with......
# Added: VS Code: NoPermissions (FileSystemError): Error: EACCES: per......
# Added: DBT Deploy: Error When trying to run the dbt project on Prod......
# Added: Homework: Ingesting FHV data from the course's GitHub mirror......
# Added: Ingesting FHV: alternative with kestra......
# Added: Homework: Ingesting NYC TLC Data......
# Added: How to set environment variable easily for any credentials......
# Added: Schema and type errors when ingesting FHV data (timestamps f......
# Added: Join Error on LocationID: "Unable to find common supertype f......
# Added: Google Looker Studio: you have used up your 30-day trial......
# Added: How does dbt handle dependencies between models?......
# Added: What is the fastest way to upload taxi data to dbt-postgres?......
# Added: dbt: Where should we create `profiles.yml`?......
# Added: dbt: Are there UI options for dbt Core like dbt Cloud?......
# Added: When configuring the profiles.yml file for dbt-postgres with......
# Added: DBT: The database is correct but I get Error with Incorrect ......
# Added: DBT: DBT allows only 1 project in free developer version.......
# Added: Power user for dbt vscode extension keeps asking to install ......
# Added: dbt Cloud: Connecting to BigQuery via Workload Identity Fede......
# Added: dbt: relationships test fails with "depends on a node named ......
# Added: Documentation or book sign not shown even after doing `dbt d......
# Added: Solving dbt-Athena library conflicts......
# Added: Can I keep my dbt project in a subfolder of my GitHub repo (......
# Added: How do I authenticate dbt with BigQuery when service account......
# Added: Why use dbt if we already have Python?......
# Added: How do I add the Bruin MCP server to VS Code?......
# Added: When should I use merge instead of append?......
# Added: Can I have multiple Bruin projects inside the same Git repos......
# Added: Bruin Python asset fails with ArrowInvalid: Cannot locate ti......
# Added: Why do downstream Bruin assets fail with 'Table does not exi......
# Added: Why does my Bruin seed asset fail with a timeout error relat......
# Added: Bruin time_interval: Why does the first run fail with a 'tab......
# Added: How to monitor RAM usage when running data pipelines locally......
# Added: Why does DuckDB show “IO Error: Could not set lock on file” ......
# Added: libduckdb.so: cannot open shared object file error when runn......
# Added: PySpark on Windows: "Python was not found; run without argum......
# Added: Cannot find Spark jobs UI at localhost......
# Added: Following 5.2.1, I am getting an error - Head:cannot open ‘t......
# Added: Error: java.io.FileNotFoundException......
# Added: Which type of SQL is used in Spark? Postgres? MySQL? SQL Ser......
# Added: The spark viewer on localhost:4040 was not showing the curre......
# Added: Spark: BigQuery connector Automatic configuration......
# Added: How can I read a small number of rows from the parquet file ......
# Added: DataType error when creating Spark DataFrame with a specifie......
# Added: Remove white spaces from column names in Pyspark......
# Added: Compression Error: zcat output is gibberish, seems like stil......
# Added: Connecting from local Spark to GCS: Spark does not find my G......
# Added: How do you read data stored in GCS on pandas with your local......
# Added: TypeError when using spark.createDataFrame function on a pan......
# Added: MemoryManager: Total allocation exceeds 95.00% (1,020,054,72......
# Added: hadoop “wc -l” is giving a different result than shown in th......
# Added: Dataproc: ERROR: (gcloud.dataproc.jobs.submit.pyspark) The r......
# Added: lServiceException: 401 Anonymous caller does not have storag......
# Added: GCP: py4j.protocol.Py4JJavaError......
# Added: Repartition the Dataframe to 6 partitions using df.repartiti......
# Added: Jupyter Notebook or SparkUI not loading properly at localhos......
# Added: Dataproc: "Insufficient SSD_TOTAL_GB quota" when creating a ......
# Added: How can I calculate the duration between two Spark timestamp......
# Added: Dataproc Qn: Is it essential to have a VM on GCP for running......
# Added: Setting JAVA_HOME with Homebrew on Apple Silicon (M1/M2/M3 M......
# Added: Subnetwork 'default' does not support Private Google Access ......
# Added: How do you share a DataFrame across multiple Spark sessions?......
# Added: How do I use Spark with BigQuery as a data source and sink?......
# Added: Why does casting TIMESTAMP_NTZ to BIGINT fail in Spark, and ......
# Added: Why does Spark write multiple parquet files after repartitio......
# Added: How many records are stored in each partition/parquet file w......
# Added: Why does max(trip_distance) return extremely large values in......
# Added: What is the difference between a Spark application, job, sta......
# Added: Spark: Is working, however, nothing appears in the Spark UI ......
# Added: How do I connect PySpark to BigQuery?......
# Added: Docker: Could not start docker image "control-center" from t......
# Added: Module “kafka” not found when trying to run producer.py......
# Added: ModuleNotFoundError: No module named 'avro'......
# Added: What is the use of Redpanda?......
# Added: Negsignal:SIGKILL while converting data files to parquet for......
# Added: resources/rides.csv is missing......
# Added: Kafka: Python videos have low audio and are hard to follow u......
# Added: Kafka Python Videos: Rides.csv......
# Added: kafka.errors.NoBrokersAvailable: NoBrokersAvailable......
# Added: Kafka homework Q3: There are options that support the scalin......
# Added: Docker: How to fix docker compose error: Error response from......
# Added: Python Kafka: ./build.sh: Permission denied Error......
# Added: Python Kafka: ‘KafkaTimeoutError: Failed to update metadata ......
# Added: Python Kafka: ./spark-submit.sh streaming.py - ERROR Standal......
# Added: Python Kafka: ./spark-submit.sh streaming.py - How to check ......
# Added: Python Kafka: ./spark-submit.sh streaming.py Error: py4j.pro......
# Added: Java Kafka: <project_name>-1.0-SNAPSHOT.jar errors: package ......
# Added: Streaming: installing dependencies for the Python avro examp......
# Added: Can I use the Faust library for the streaming module?......
# Added: Java Kafka: How to run producer/consumer/kstreams/etc in ter......
# Added: Java Kafka: When running the producer/consumer/etc java scri......
# Added: Java Kafka: Tests are not picked up in VSCode......
# Added: Confluent Kafka: Where can I find schema registry URL?......
# Added: How do I check compatibility of local and container Spark ve......
# Added: How to fix the error "ModuleNotFoundError: No module named '......
# Added: How do you manually manage offsets in a Kafka consumer?......
# Added: PyFlink session window job fails with 'please declare primar......
# Added: Why does the tumbling window job run successfully but the Po......
# Added: Why does the PyFlink streaming job fail with a JSON deserial......
# Added: How to Inspect Messages in a Kafka Topic Using Offsets?......
# Added: How do I avoid backpressure in a Flink streaming job?......
# Added: Spark Streaming: How do I read from multiple topics in the s......
# Added: How is my capstone project going to be evaluated?......
# Added: Can I collaborate with others on the capstone project?......
# Added: Project 1 & Project 2......
# Added: Does anyone know nice and relatively large datasets?......
# Added: Data Transformation from Databricks to Azure SQL DB......
# Added: Orchestrating dbt with Airflow......
# Added: Orchestrating DataProc with Airflow......
# Added: Key Vault in Azure cloud stack......
# Added: How to run a dbt-core project as an Airflow Task Group on Go......
# Added: How can I run UV in Kestra without installing it on every fl......
# Added: Is it ok to use NY_Taxi data for the project?......
# Added: How to use dbt-core with Athena?......
# Added: Which set-up should I use for my dlt homework?......
# Added: How do I install the necessary dependencies to run the code?......
# Added: Other packages needed but not listed......
# Added: Homework: dlt Exercise 3 - Merge a generator concerns......
# Added: Problem with importing the dlt or dlt.sources module......
# Added: How to set credentials in Google Colab notebook to connect t......
# Added: How do I set up credentials to run dlt in my environment (no......
# Added: Make DLT comply with the XDG Base Dir Specification......
# Added: Embedding dlt into Apache Airflow......
# Added: Embedding dlt into Kestra......
# Added: Loading dlt exports from GCS filesystems (compressed by defa......
# Added: How does dlt handle schema evolution?......
# Added: What is the difference between rest_api_source({...}) and @d......
# Added: How do I add the dlt MCP server in VS Code?......
# Added: REST API pagination should start at page 1 and stop when the......
# Added: How to query data when dlt normalizes column names to lowerc......
# Added: Why might some API response fields be missing after a dlt pi......
# Added: How do I generate the AGENTS.md file for Codex in dlt?......
# Added: Do I need to pay for any platform or data for this course?......
# Added: Do I need a finance background to take this course?......
# Added: My Python or Pandas skills feel too weak for the course. How......
# Added: Can I use Excel instead of Python and notebooks?......
# Added: What books do you recommend for the course?......
# Added: How much time does the course take?......
# Added: Will the course provide starter or boilerplate code to build......
# Added: What tech stack does the course use?......
# Added: Does the course cover news and sentiment analysis, and can L......
# Added: Does the approach work for crypto, forex, ETFs and other ass......
# Added: Do I need to know statistics or have trading experience?......
# Added: Will this course make me a profitable trader or help me get ......
# Added: Will I have enough skills to start my own analysis and inves......
# Added: Does the course cover technical and fundamental analysis?......
# Added: What returns has the instructor achieved with algorithmic tr......
# Added: Do I need to open a broker account to take the course?......
# Added: Which broker should I use - Revolut, Charles Schwab or Inter......
# Added: Is there a valid certificate of completion?......
# Added: Does the course focus only on short-term trading, or also lo......
# Added: What is a quant?......
# Added: How expensive are trading commissions, and won't frequent tr......
# Added: Is there a disclaimer about financial losses from trading?......
# Added: Can I use the course for non-US markets, such as Indian stoc......
# Added: If the efficient market hypothesis says you can't beat the m......
# Added: How much math do I need to know?......
# Added: Can you share references for the theoretical concepts behind......
# Added: Does the instructor use named technical-analysis strategies ......
# Added: Does the course follow the existing PythonInvest basic finan......
# Added: What are the latest ML research topics for the stock market,......
# Added: Do I need a GPU (e.g. a Colab GPU) for this course?......
# Added: Is classic financial modeling (e.g. discounted cash flows) c......
# Added: Where can I find the course repo with the slides and code?......
# Added: Are the lectures recorded, and where are the playlists?......
# Added: How should I prepare alongside the course to land a quant jo......
# Added: Do I need to know time series before starting?......
# Added: Does this course overlap with the MLOps Zoomcamp, and can I ......
# Added: Does the course focus on analytics, predictions or coding?......
# Added: Can I start now or should I wait for the official launch?......
# Added: Will the course teach how to analyze the impact of tariffs o......
# Added: What is the overall timeline and structure of the course?......
# Added: What career outcomes can I expect, and is this a good first ......
# Added: Should I do the ML Zoomcamp first, and how much coding do I ......
# Added: Does building an accurate ML model actually beat simple tech......
# Added: Can you show an example Streamlit dashboard from the course?......
# Added: How does the 2025 edition differ from the previous one?......
# Added: How do I handle invalid or delisted tickers in yfinance (e.g......
# Added: yf.Ticker.calendar or .financials returns "no summary info".......
# Added: Should I use Close or Adj.Close, and how do I get dividends?......
# Added: yfinance is "for studies only" - where do I get reliable or ......
# Added: Are there free stock screeners I can use?......
# Added: pandas-datareader doesn't seem to be maintained anymore - sh......
# Added: How do I compute the future growth columns (growth_future_1d......
# Added: ta-lib won't install on Windows. What works?......
# Added: How do I load the large parquet data file in Colab?......
# Added: After merging DataFrames I get Adj Close_x and Adj Close_y i......
# Added: How much historical data is enough - 1, 2 or 10 years?......
# Added: Can I add fundamental analysis to the Colab notebook?......
# Added: My modeling DataFrame has 300+ feature columns. How do I man......
# Added: Colab disconnects during hyperparameter tuning - is Colab Pr......
# Added: GitHub only shows part of the module notebook. Is the notebo......
# Added: What baseline (unconditional win rate) are the models compar......
# Added: How did you choose the ARIMA parameters (2,1,2) - cross-vali......
# Added: Should I use SARIMA / SARIMAX (seasonal ARIMA) instead?......
# Added: Why did the simple ARIMA model outperform the market on the ......
# Added: Would you actually use this ARIMA model in production for re......
# Added: Should I build one model per stock, or a single model coveri......
# Added: Should I use very old data (back to 1999) or only the last f......
# Added: What happens if I combine the models into an ensemble (e.g. ......
# Added: We train a regression model and use it like a classifier - c......
# Added: Did you try XGBoost with lagged features for time-series pre......
# Added: Did you try TimeGPT or LSTM for time-series prediction?......
# Added: Why can't I reproduce the exact predictions for homework 3 q......
# Added: I skipped homework 3 questions 3 and 4 because I lack advanc......
# Added: Does the trained model require trading the exact same set of......
# Added: Should the trading simulation buy at the next day's open or ......
# Added: Do we optimize returns pre-tax or after-tax, and can I inclu......
# Added: What practical trading scenarios does the simulation module ......
# Added: Why does the deployment use Digital Ocean instead of AWS?......
# Added: Can the free data sources handle high request rates (e.g. 10......
# Added: Can I use GitHub Actions to fetch data, apply an already-tra......
# Added: How do I run the model live against real market data instead......
# Added: Does the course use real-time or streaming market data?......
# Added: Will the course teach how to connect to a broker's API and p......
# Added: Is the instructor available for proprietary trading, or is t......
# Added: Is a machine learning model required for the capstone projec......
# Added: How many tickers should my project use?......
# Added: Can I do my project on crypto instead of stocks?......
# Added: Can I reuse this project for the MLOps Zoomcamp, or use meth......
# Added: The capstone ideas I brainstormed in homework 1 - am I locke......
# Added: Is the project solo, or can I work in a group?......
# Added: Can I finish early and get my certificate sooner?......
# Added: Can I start working on my project right away?......
# Added: Can I use generative AI for the capstone project?......
# Added: How do I access the course modules and materials?......
# Added: Are the sessions live or recorded?......
# Added: Where do I submit the homework?......
# Added: How are homework assignments scored?......
# Added: How do I create a GitHub repository to submit my homework?......
# Added: What are the prerequisites and system requirements for this ......
# Added: Am I too late to join the course?......
# Added: Which free AI tools can I use for the course?......
# Added: Does this course cover AI engineering topics like LangChain,......
# Added: If AI writes the code, do I still need to understand it, and......
# Added: Can I take the course on a locked-down work laptop without a......
# Added: Will the course teach debugging AI-generated code or prompt ......
# Added: Can I use Codex, Gemini CLI, or another assistant instead of......
# Added: Is there an IDE with unlimited access to coding agents, and ......
# Added: Should I use pip or uv?......
# Added: How do people record their screen for the demo videos?......
# Added: Which assistant mode should I use - agent, edit, or ask?......
# Added: What do I need to install for the course?......
# Added: For deployment, should I use a monolith (one container) or s......
# Added: I get CORS errors locally after building the frontend. What'......
# Added: Where can I find the prompts Alexey used in the videos?......
# Added: OpenAI Codex models (e.g. gpt-5.1-codex) time out or can't b......
# Added: Module 3 (MCP) feels too hard. How should I approach it?......
# Added: MCP Inspector shows a 'Connection Error'. Can I skip it?......
# Added: How do I get an MCP server running in a Docker container to ......
# Added: Do I need prior Django or Python knowledge?......
# Added: Which Python version is compatible with Django 5.2.9?......
# Added: What's a good Plan vs Act workflow, and should I switch mode......
# Added: How do I make the agent commit to git regularly and keep tra......
# Added: Will this course teach me to build a production AI agent?......
# Added: Railway can't read the port from railway.toml. How do I fix ......
# Added: Why serve the frontend and backend from a single Docker cont......
# Added: Do I have to use Python/Django for the final project, or can......
# Added: Can I mix machine learning into my project?......
# Added: My project pulls YouTube transcripts and my IP gets blocked.......
# Added: For a RAG-based project, is there anything better than seman......
# Added: What are some Claude Code tips and common fixes?......
# Added: How do I define rules in Antigravity?......
# Added: I can't sign in with Google on Antigravity. What can I do?......
# Added: Should I use Claude Code Skills?......
# Added: Can I make Antigravity or GitHub Copilot use the latest onli......
# Added: I just discovered the course. Can I still join?......
# Added: Course: I have registered for the LLM Zoomcamp. When can I e......
# Added: What is the video/zoom link to the stream for the “Office Ho......
# Added: How should I start the course and follow the weekly workflow......
# Added: Leaderboard: I am not on the leaderboard / how do I know whi......
# Added: Certificate: Can I follow the course in a self-paced mode an......
# Added: I missed the first homework - can I still get a certificate?......
# Added: Homework: Why does the content keep changing?......
# Added: When will the course be offered next?......
# Added: Are there any lectures/videos? Where are they?......
# Added: Where can I track the LLM Zoomcamp syllabus, deadlines, home......
# Added: Are there live sessions or office hours for each module?......
# Added: Can I use Bluesky for learning in public credits?......
# Added: Where is the LLM Zoomcamp Telegram channel?......
# Added: Why are we not using Langchain in the course?......
# Added: OpenAI: Error when running OpenAI responses.create command......
# Added: OpenAI: Error: RateLimitError: Error code: 429 -......
# Added: OpenAI: How much will I have to spend to use the Open AI API......
# Added: OpenAI: Do I have to subscribe and pay for Open AI API for t......
# Added: Authentication: Why is my OPENAI_API_KEY not found in the Ju......
# Added: How to store and load API keys using .env file......
# Added: Can I use a model or provider different from the one recomme......
# Added: How do I start using Google Gemini models in the Module 1 no......
# Added: Ollama: How to install Ollama?......
# Added: Connection refused error when prompting Ollama RAG......
# Added: OpenAI: Why does my token count differ from what OpenAI repo......
# Added: API keys: how do I set them once and not re-export every ter......
# Added: How should I choose field weights for minsearch or another s......
# Added: How should I prepare documents for RAG?......
# Added: uv says Failed to hardlink files in Codespaces. Is it an err......
# Added: dotenv is not recognized. What should I install?......
# Added: Can I run the course locally instead of Codespaces?......
# Added: What happens to code saved in Codespaces if I do not commit ......
# Added: WSL2: ResponseError: model requires more system memory (X.X ......
# Added: What are tools and functions in agentic RAG?......
# Added: Any free models with tool use support?......
# Added: Agents: "AttributeError: 'str' object has no attribute 'outp......
# Added: I am using Azure OpenAI and I am still getting an error of E......
# Added: Where can I find the homework questions?......
# Added: Homework: Returning Empty list after filtering my query (HW ......
# Added: OpenRouter: Error code 402 when calling responses.create (ma......
# Added: What does it mean to point RAG at the chunk index in Module ......
# Added: Do homework answers need to match the options exactly?......
# Added: What should I do if homework questions feel unclear?......
# Added: How do I get token counts for Module 1 homework if I use a d......
# Added: What are embeddings?......
# Added: Warning: 'model "multi-qa-mpnet-base-dot-v1" was made on sen......
# Added: Why was .dot(...) used directly to compute cosine similarity......
# Added: Vector search: should I embed the question, the answer, or b......
# Added: What is the cosine similarity?......
# Added: Why does cosine similarity reduce to a matrix multiplication......
# Added: Do I need a new GitHub repo for Module 2, or just a new code......
# Added: Evaluation: "JSONDecodeError: Expecting value" when generati......
# Added: Evaluation: Jupyter kernel crashes when embedding the ground......
# Added: Evaluation: hitting rate limits while generating the ground-......
# Added: In Windows OS: OSError: [WinError 126] The specified module ......
# Added: OperationalError when running python prep.py: psycopg2. Oper......
# Added: How set Pandas to show entire text content in a column. Usef......
# Added: How to normalize vectors in a Pandas DataFrame column (or Pa......
# Added: How to compute the quantile or percentile of Pandas DataFram......
# Added: How can I remove all Docker containers, images, and volumes,......
# Added: Session State: I want the user to only be able to give feedb......
# Added: Docker: When trying to run a streamlit app using docker-comp......
# Added: Is it a group project?......
# Added: Do we submit 2 projects, what does attempt 1 and 2 mean?......
# Added: Does the competition count as the capstone?......
# Added: How is my capstone project going to be evaluated?......
# Added: When and how will we be assigned projects for review/grading......
# Added: I’ve already submitted my project. Why can’t I review any pr......
# Added: How can I find some good ideas or datasets for the project?......
# Added: Project: do I need an orchestration tool (Airflow, Mage, Kes......
# Added: Project: how do I evaluate a recommender-style RAG (no obvio......
# Added: Project: my corpus is large (long PDFs, many paragraphs). Wh......
# Added: Project: what does "reproducibility" mean — do reviewers nee......
# Added: Can I use a programming language other than Python (for exam......
# Added: Where can I find previous LLM Zoomcamp projects?......
# Added: Do I need to announce or reserve my project idea?......
# Added: Can I use the workshop materials for my own projects or shar......
# Added: How to set up a new dlt project when loading from cloud?......
# Added: There is an error when opening the table using `dbtable = db......
# Added: There is an error when running main(): FileNotFoundError: Ta......
# Added: How do I know which tables are in the db?......
# Added: Does DLT have connectors to ClickHouse or StarRocks?......
# Added: Notebook does not have secret access or 401 Client Error: Un......
# Added: Error: How to fix requests library only installs v2.28 inste......
# Added: I forgot if I registered, can I still join the zoomcamp?......
# Added: Is it going to be live? When?......
# Added: Course - Can I still join the course after the start date?......
# Added: Course: How do I start?......
# Added: Course - Can I still graduate when I didn’t complete homewor......
# Added: Certificate - Can I follow the course in a self-paced mode a......
# Added: What’s the difference between the 2023 and 2022 course?......
# Added: Cohort: What’s the difference between the 2024 and 2023 cour......
# Added: Cohort: Will there be a 2024 Cohort? When will the 2024 coho......
# Added: Cohort: I missed the current cohort, when is the next cohort......
# Added: Homework: What if my answer is not exactly the same as the c......
# Added: Homework: where can I find the schedule and/or deadlines of ......
# Added: Homework: when is the homework due date?......
# Added: Homework: Why is the experiment in question 6 taking so long......
# Added: Homework: I am getting conflicts on server ports and cannot ......
# Added: Homework 3, 2025 Cohort - Do I have to use MAGE as the orche......
# Added: Homework: Just found this course, can I still submit homewor......
# Added: Hi, is it too late to start the course, I have ML experience......
# Added: Project: Are we free to choose our own topics for the final ......
# Added: Project: Is the capstone an individual or team project?......
# Added: Project: For the final project, is it required to be put on ......
# Added: Homework and Leaderboard: what is the system for points in t......
# Added: What exactly is a learning-in-public post?......
# Added: Leaderboard: I am not on the leaderboard / how do I know whi......
# Added: Error: creating Lambda Function (...): InvalidParameterValue......
# Added: Criteria for getting a certificate?......
# Added: Is completion of Homework necessary for a certificate?......
# Added: Where do I find the updated homework playlist and cohort-spe......
# Added: Can I submit and update my project attempt multiple times be......
# Added: Opening Jupyter in VSCode......
# Added: Launching Jupyter notebook from codespace VM......
# Added: Configuring Github to work from the remote VM......
# Added: Opening Jupyter in AWS......
# Added: WSL: instructions......
# Added: Git: Created repo without .gitignore......
# Added: .gitignore: how-to......
# Added: AWS: Suggestions......
# Added: IBM Cloud an alternative for AWS......
# Added: AWS costs:......
# Added: Is the AWS free tier enough for doing this course?......
# Added: AWS EC2: this site can’t be reached......
# Added: Unprotected private key file!......
# Added: AWS EC2 instance constantly drops SSH connection......
# Added: AWS EC2: How do I handle changing IP addresses on restart?......
# Added: VS Code crashes when connecting to Jupyter......
# Added: My connection to my GCP VM instance keeps timing out when I ......
# Added: X has 526 features, but expecting 525 features......
# Added: Missing dependencies......
# Added: squared Option Not Available in mean_squared_error......
# Added: No RMSE value in the options......
# Added: How to replace distplot with histplot......
# Added: KeyError: 'PULocationID'  or  'DOLocationID'......
# Added: ImportError: Unable to find a usable engine; tried using: ‘p......
# Added: Reading large parquet files......
# Added: Kernel getting killed during assignment tasks on local......
# Added: What is the difference between label and one-hot encoding?......
# Added: Distplot takes too long......
# Added: RMSE on test set too high......
# Added: ictVectorizerA: Alexey’s answer......
# Added: Why did we not use OneHotEncoder(sklearn) instead of DictVec......
# Added: Clipping outliers......
# Added: Replacing NaNs for pickup location and drop off location wit......
# Added: Slightly different RMSE......
# Added: Extremely low RMSE......
# Added: Enabling Auto-completion in Jupyter Notebook......
# Added: Downloading the data from the NY Taxis datasets gives error:......
# Added: Using PyCharm & Conda env in remote development......
# Added: Running out of memory......
# Added: Activating Anaconda env in .bashrc......
# Added: The feature size is different for training set and validatio......
# Added: Permission denied (publickey) Error (when you remove your pu......
# Added: Overfitting: Absurdly high RMSE on the validation dataset......
# Added: Can’t import sklearn......
# Added: Install docker in WSL2 without installing Docker Desktop......
# Added: Zero elements in sparse matrix (AKA when dictionary vectoriz......
# Added: Using a docker image as development environment (Linux)......
# Added: Use uv as a package manager......
# Added: I get `TypeError: got an unexpected keyword argument 'square......
# Added: Visualizing outliers in large datasets with Seaborn: Boxplot......
# Added: Reading parquet files with Pandas (pyarrow dependency)......
# Added: Kernel died during Model Training on Github Codespaces......
# Added: Do we absolutely need to save data to disk? Can we use it di......
# Added: Access Denied at Localhost:5000 - Authorization Issue......
# Added: Connection in use: ('127.0.0.1', 5000)......
# Added: Could not convert string to float - ValueError......
# Added: Experiment not visible in MLflow UI......
# Added: Metrics not visible in mlflow UI......
# Added: Unable to create new Experiment......
# Added: Hash Mismatch Error with Package Installation......
# Added: How to Delete an Experiment Permanently from MLFlow UI......
# Added: How to Update Git Public Repo Without Overwriting Changes......
# Added: Image size of 460x93139 pixels is too large. It must be less......
# Added: MlflowClient object has no attribute 'list_experiments'......
# Added: MLflow Autolog not working......
# Added: MLflow URL ([127.0.0.1:5000](http://127.0.0.1:5000)) doesn't......
# ...
# Added: Your Pipfile.lock (221d14) is out of date (during Docker bui......
# Added: Completed creating the environment locally but could not fin......
# Added: Waitress on Windows / Git Bash: "waitress-serve: command not......
# Added: Warning: the environment variable LANG is not set!......
# Added: Terminal Used in Week 5 videos:......
# Added: Waitress: waitress-serve shows Malformed application......
# Added: Testing HTTP POST requests from command line using curl......
# Added: Error: NotSupportedError - You can use "eb local" only with ......
# Added: Requests Error: No connection adapters were found for 'local......
# Added: Getting the same result......
# Added: Docker: Trying to run a docker image I built but it says it’......
# Added: How do I copy files from my local machine to a docker contai......
# Added: How do I copy files from a different folder into a Docker co......
# Added: AWS Elastic Beanstalk: I can’t create the environment with t......
# Added: Docker: Dockerfile missing when creating the AWS ElasticBean......
# Added: eb create: ERROR: CommandError - git could not find the HEAD......
# Added: Why doesn’t the eb create command use the latest version of ......
# Added: Elastic Beanstalk ‘eb create’: ERROR   Creating Auto Scaling......
# Added: AWS: Discontinues Support for Launch Configurations......
# Added: Default VPC Error when deploying to AWS Elastic Beanstalk:......
# Added: What's the advantage of using Gunicorn with Flask in Docker?......
# Added: Fix warning: Python 3.12 was not found on your system… Neith......
# Added: Pipenv: how do I use a specific Python version (e.g. 3.11)?......
# Added: Pipenv is taking forever to lock file. I have deleted the lo......
# Added: How to save/download jupyter notebook to python script......
# Added: Does it matter if we let the Python file create the server o......
# Added: No module named ‘ping’?......
# Added: docker: Error response from daemon: failed to create task fo......
# Added: Can I use pre-trained models and focus on deployment?......
# Added: How to run a FastAPI app for serving a Python pickle-based m......
# Added: UserWarning: Trying to unpickle estimator from version X.Y.Z......
# Added: pipenv install fails with 'Failed to lock Pipfile.lock' or '......
# Added: ModuleNotFoundError: No module named 'numpy._core' when runn......
# Added: Docker container fails: 'gunicorn: executable file not found......
# Added: Apple Silicon (M1/M2/M3): docker run says 'requested image's......
# Added: Docker image size doesn't match any of the homework options......
# Added: eb create fails: 'Creating Auto Scaling launch configuration......
# Added: eb local run: 'NotSupportedError - You can use eb local only......
# Added: After eb init, EB ignores my profile / picks the wrong regio......
# Added: Can I use FastAPI instead of Flask?......
# Added: ConnectionRefusedError [Errno 61/111] Connection refused whe......
# Added: Module 5 has both a Pipenv + Flask version and a uv + FastAP......
# Added: After uv add, uv.lock has the package but pyproject.toml sho......
# Added: Homework 5: ModuleNotFoundError: No module named 'sklearn' i......
# Added: How do I deploy my Dockerized API to Render (free tier)?......
# Added: Docker: I cannot pull the image with docker pull command......
# Added: Error: failed to compute cache key: "/model2.bin" not found:......
# Added: Homework Q6: Which model and dict vectorizer to use?......
# Added: The homework instructions say Docker file has a new pipeline......
# Added: I have M1 and don't use Docker Desktop.......
# Added: XGBoost: TypeError: Expecting a sequence of strings for feat......
# Added: How to ensure "none" values are not interpreted as NaN when ......
# Added: How to fix when %%capture output is not working in Google Co......
# Added: How to get the training and validation metrics from XGBoost?......
# Added: How to solve regression problems with random forest in sciki......
# Added: ValueError: feature_names must be string, and may not contai......
# Added: Q6: ValueError or TypeError while setting xgb.DMatrix(featur......
# Added: How to Install Xgboost......
# Added: What is eta in XGBoost......
# Added: What is the difference between bagging and boosting?......
# Added: Capture stdout for each iteration of a loop separately......
# Added: ValueError: continuous format is not supported......
# Added: What is one method to visualize decision trees?......
# Added: ValueError: Unknown label type: 'continuous'......
# Added: Different values of AUC, each time code is re-run......
# Added: DictVectorizer: feature names......
# Added: Does it matter if we let the Python file create the server o......
# Added: Visualize Feature Importance by using horizontal bar chart......
# Added: RMSE using metrics.root_meas_square()......
# Added: Features Importance graph......
# Added: xgboost.core.XGBoostError: This app has encountered an error......
# Added: Information Gain......
# Added: Data Leakage......
# Added: Saving and loading Xgboost......
# Added: Why does DecisionTreeClassifier and DecisionTreeRegressor no......
# Added: Traversing feature names and feature importance values......
# Added: Which XGBoost parameters are the most important to start wit......
# Added: How to get feature importance for XGboost model......
# Added: Reading the homework CSV converts the string 'None' to NaN......
# Added: Random Forest gives the same RMSE for all n_estimators value......
# Added: Homework Q3: What does it mean that RMSE stops improving?......
# Added: Could I partner up for the mid and final projects?......
# Added: Are projects solo or collaborative/group work?......
# Added: What modules, topics, problem-sets should a midterm/capstone......
# Added: How to conduct peer reviews for projects?......
# Added: Learning in public links for the projects......
# Added: My dataset is too large and I can't load it in GitHub. Does ......
# Added: What do I need to earn the certificate?......
# Added: What datasets are acceptable for projects?......
# Added: I did the first two projects and skipped the last one so I w......
# Added: How many models should I train?......
# Added: Do you pass a project based on the average of everyone else’......
# Added: Does your mid term project need to use a neural network to g......
# Added: How are projects run and graded?......
# Added: Can I submit a medical project for the final project if depl......
# Added: Can I use Streamlit alone as the deployment for my project?......
# Added: Can I use FastAPI / PyTorch / a different framework than wha......
# Added: For the midterm, do I need to train multiple models or is on......
# Added: How to install Tensorflow in Ubuntu WSL2......
# Added: How to use Kaggle for Deep Learning?......
# Added: How to use Google Colab for Deep Learning?......
# Added: How to install CUDA & cuDNN on Ubuntu 22.04......
# Added: ValueError: Unable to load weights saved in HDF5 format into......
# Added: Cloning into 'clothing-dataset'... Host key verification fai......
# Added: The same accuracy on epochs......
# Added: Model breaking after augmentation – high loss + bad accuracy......
# Added: Missing channel value error while reloading model:......
# Added: How to unzip a folder with an image dataset and suppress out......
# Added: How does keras flow_from_directory know the names of classes......
# Added: How are numeric class labels determined in flow_from_directo......
# Added: What if your accuracy and std training loss don’t match HW?......
# Added: Using multi-threading for data generation in “model.fit()”......
# Added: Reproducibility with TensorFlow using a seed point......
# Added: Can we use PyTorch for this lesson/homework?......
# Added: Keras: Model training fails with “Failed to find data adapte......
# Added: Running ‘nvidia-smi’ in a loop without using ‘watch’......
# Added: Checking GPU and CPU utilization using ‘nvitop’......
# Added: Where does the number of input features to the first Linear ......
# Added: Sequential vs. Functional Model Modes in Keras (TF2)......
# Added: Out of memory errors when running tensorflow......
# Added: How did I resolve the out of memory (OOM) issue when trainin......
# Added: Model training very slow in google colab with T4 GPU......
# Added: Using image_dataset_from_directory instead of ImageDataGener......
# Added: How can data augmentation improve model performance?......
# Added: How many feature maps are produced by a PyTorch Conv2D layer......
# Added: ImportError: cannot import name 'load_img' from 'tensorflow.......
# Added: model.save_weights(...) fails with newer Keras......
# Added: Should I install the CUDA build of PyTorch, or is CPU-only e......
# Added: import tensorflow fails: 'TypeError: Unable to convert funct......
# Added: Where is the model for week 9?......
# Added: Why ONNX Runtime for DL deployment?......
# Added: Executing the command echo ${REMOTE_URI} returns nothing.......
# Added: Getting a syntax error while trying to get the password from......
# Added: Pass many parameters in the model at once......
# Added: Getting ERROR [internal] load metadata for public.ecr.aws/la......
# Added: Problem: 'ls' is not recognized as an internal or external c......
# Added: ImportError: generic_type: type "InterpreterWrapper" is alre......
# Added: WARNING: You are using pip version 22.0.4; however, version ......
# Added: How to do AWS configure after installing awscli......
# Added: Object of type float32 is not JSON serializable......
# Added: Error with the line interpreter.set_tensor(input_index, X)......
# Added: How to easily get file size in PowerShell terminal?......
# Added: How do Lambda container images work?......
# Added: How to use AWS Serverless Framework to deploy on AWS Lambda ......
# Added: Error building docker image on M1 Mac......
# Added: Error invoking API Gateway deploy API locally......
# Added: Error: Could not find a version that satisfies the requireme......
# Added: Error: A module that was compiled using NumPy 1.x cannot be ......
# Added: Docker: run error......
# Added: Docker: Save Docker Image to local machine and view contents......
# Added: Running out of space for AWS instance.......
# Added: Using Tensorflow 2.15 for AWS deployment......
# Added: Command aws ecr get-login --no-include-email returns “aws: e......
# Added: What IAM permission policy is needed to complete Week 9: Ser......
# Added: Docker: Temporary failure in name resolution......
# Added: Keras model *.h5 doesn’t load. Error: weight_decay is not a ......
# Added: How to test AWS Lambda + Docker locally?......
# Added: "Unable to import module 'lambda_function': No module named ......
# Added: Install Docker (udocker) in Google Colab......
# Added: Lambda API Gateway errors:......
# Added: Unable to run pip install tflite_runtime from github wheel l......
# Added: Python 3.12 vs TF Lite 2.17......
# Added: How can I monitor and maintain models deployed on AWS Lambda......
# Added: How to Use AWS SAM CLI to Create a Lambda Function as a Cont......
# Added: Tflite_runtime unable to install......
# Added: Why am I getting the 'image manifest, config or layer media ......
# Added: HW9 Docker: 'A module that was compiled using NumPy 1.x cann......
# Added: HW9 PyTorch/ONNX: model expects (1, 3, 200, 200) but my prep......
# Added: HW9 prediction value is far from the answer options (e.g. 0.......
# Added: AWS Lambda: 'The image manifest, config or layer media type ......
# Added: What tools are recommended for setting up a local Kubernetes......
# Added: How do you determine the minimum number of replicas needed t......
# Added: Allocator (GPU_0_bfc) ran out of memory......
# Added: Problem with recent version of protobuf......
# Added: WSL: Cannot Connect To Docker Daemon......
# Added: HPA instance doesn’t run properly......
# Added: HPA instance doesn’t run properly (easier solution)......
# Added: Pods not starting......
# Added: Windows pip install: "OSError [WinError 5] Access is denied"......
# Added: TypeError: Descriptors cannot not be created directly.......
# Added: How to install easily kubectl on Windows?......
# Added: Install kind through choco library......
# Added: Install Kind via Go package......
# Added: The connection to the server localhost:8080 was refused - di......
# Added: Docker: Running out of storage after building many docker im......
# Added: Homework: In HW10 Q6 what does it mean “correct value for CP......
# Added: Why do CPU values for Kubernetes deployment.yaml look like "......
# Added: Kind: cannot load docker image......
# Added: What’s the difference between Flask and FastAPI for model de......
# Added: 'kind' is not recognized as an internal or external command,......
# Added: Running kind on Linux with Rootless Docker or Rootless Podma......
# Added: Kubernetes-dashboard......
# Added: Correct AWS CLI version for eksctl......
# Added: TypeError: __init__() got an unexpected keyword argument 'un......
# Added: Command aws ecr get-login --no-include-email returns "aws: e......
# Added: Error downloading tensorflow/serving:2.7.0 on Apple M1 Mac......
# Added: Illegal instruction error when running tensorflow/serving im......
# Added: HPA: CPU metrics don't show......
# Added: HW10 Autoscaling (optional) command does not work......
# Added: Error validating 'deployment.yaml' when running kubectl appl......
# Added: Why do I fail to create a cluster with Kind in Module 10 Kub......
# Added: HPA shows cpu: <unknown>/20% and never scales (kind cluster)......
# Added: Module 10 / Apple Silicon: tensorflow/serving:2.7.0 exits wi......
# Added: Module 10 pipenv install grpcio==1.42.0 ... tensorflow-proto......
# Added: Why do I need to provide a train.py file when I already have......
# Added: Loading the Image with PILLOW library and converting to nump......
# Added: Is a train.py file necessary when you have a train.ipynb fil......
# Added: Is there a way to serve up a form for users to enter data fo......
# Added: [Errno 12] Cannot allocate memory in AWS Elastic Container S......
# Added: Pickle error: can’t get attribute XXX on module __main__......
# Added: How to handle outliers in a dataset?......
# Added: Reproducibility: Do we have to run everything?......
# Added: Model too big......
# Added: Permissions to push docker to Google Container Registry......
# Added: Error when running ImageDataGenerator.flow_from_dataframe......
# Added: Error: UnidentifiedImageError: cannot identify image file......
# Added: [pipenv.exceptions.ResolutionFailure]: Warning: Your depende......
# Added: Error decoding JSON response: Expecting value: line 1 column......
# Added: Free / cheap cloud alternatives for deploying my Docker imag......
# Added: Chart for classes and predictions......
# Added: Convert dictionary values to Dataframe table......
# Added: Kitchenware Classification Competition Dataset Generator......
# Added: I may end up submitting the assignment late. Would it be eva......
# Added: Does the GitHub repository need to be public?......
# Added: Which IDE is recommended for machine learning?......
# Added: How to use wget with Google Colab?......
# Added: Features in scikit-learn?......
# Added: Matplotlib: When I plotted using Matplotlib to check if the ......
# Added: Reproducibility in different OS......
# Added: Deploying to Digital Ocean......
# Added: Is it best to train your model only on the most important fe......
# Added: How can I work with very large datasets, e.g. the New York Y......
# Added: Can I do the course in other languages, like R or Scala?......
# Added: Is use of libraries like [fast.ai](http://fast.ai/) or Huggi......
# Added: Docker: Flask image was built and tested successfully, but t......
# Added: Any advice for adding the Machine Learning Zoomcamp experien......
# Added: How do I install extra packages on Google Colab or Kaggle?......
# Added: If you are working in the terminal on your computer in WSL a......
# Added: Random seeds give different results between Jupyter local, C......
# Added: How do I convert a Jupyter notebook to a .py script?......
# Added: GitHub 429: Too Many Requests when downloading a CSV via wge......
# Added: Pandas ParserError: Expected 1 fields in line N, saw M when ......
# Added: Python 3.13 / 3.14 breaks my code (sklearn / numpy / etc.)......
# Added: My homework answer doesn't match any of the options......
